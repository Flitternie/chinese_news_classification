# %%
import os
import re
import json
import pandas as pd

doc_topics = ['会议', '会见', '调研', '活动', '批示']
doc_topic_df = pd.DataFrame(columns=['topic_id', 'content', 'file'])      
paragraph_topic_df = pd.DataFrame(columns=['topic_id', 'content', 'file'])

# %%
def read_file(filepath):
    with open(filepath, 'r', encoding='gb18030') as f:
        content = f.read()
        content = re.sub('[\n\t\s]*', '', content)
        if '#' not in content:
            print('{}'.format(filepath))
            return None
    return content.split('#', 1)

# %%
for doc_topic in doc_topics:
    topic_folders = os.listdir("./data/{}".format(doc_topic))
    topic_folders = [folder for folder in topic_folders if folder.isdigit()]
    topic_folders.sort()
    for folder in topic_folders:
        files = os.listdir("./data/{}/{}/".format(doc_topic, folder))
        content = read_file("./data/{}/{}/type.txt".format(doc_topic, folder))
        if content:
            doc_topic_df = doc_topic_df.append({'topic_id': int(content[0].split('-')[0])-1, 'content': content[1], 'file': "{}.{}".format(doc_topic, folder)}, ignore_index=True)
        files = [file for file in files if re.match(r'p[0-9]*\.txt$', file)]
        for file in files:
            content = read_file("./data/{}/{}/{}".format(doc_topic, folder, file))
            if content:
                paragraph_topic_df = paragraph_topic_df.append({'topic_id': int(content[0].split('-')[0])-1, 'content': content[1], 'file': "{}.{}.{}".format(doc_topic, folder, file)}, ignore_index=True)

# %%
doc_topic_df.to_json(open('doc_topic.json', 'w', encoding='utf-8'), force_ascii=False, orient='records')
doc_topic_df.groupby('topic_id').count()
# Out:
#           content  file
# topic_id
# 0             425   425
# 1             131   131
# 2             206   206
# 3              90    90
# 4             101   101

# %%
paragraph_topic_df.to_json(open('paragraph_topic.json', 'w', encoding='utf-8'), force_ascii=False, orient='records')
paragraph_topic_df.groupby('topic_id').count()
# Out:
#           content  file
# topic_id
# 0             423   423
# 1              93    93
# 2             168   168
# 3              36    36
# 4              56    56
# 5             204   204
# 6             147   147
# 7              35    35
# 8              76    76
# 9             126   126
# 10             83    83
# 11            125   125
# 12            150   150
# 13             49    49
# 14             48    48
# 15            130   130
# 16            139   139
# 17            132   132
# 18            121   121
# 19             96    96
# 20             62    62
# 21             73    73
# 22            106   106
